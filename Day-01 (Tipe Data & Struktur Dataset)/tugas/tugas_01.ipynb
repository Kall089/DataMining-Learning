# %% [markdown]
# # Tugas 1: Identifikasi Tipe Data
#
# ## Deskripsi
# Diberikan dictionary berikut yang merepresentasikan data mahasiswa.
# Buatlah DataFrame dari dictionary tersebut, lalu tampilkan:
# 1. Tipe data setiap kolom menggunakan `.dtypes`
# 2. Klasifikasikan masing-masing kolom ke dalam: **Nominal, Ordinal, Interval, atau Rasio**
# 3. Simpan klasifikasi tersebut dalam dictionary `klasifikasi`

# %%
import pandas as pd
import numpy as np

data = {
    'NIM': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka'],
    'IPK': [3.45, 3.80, 2.95, 3.60, 3.10],
    'Semester': [4, 6, 2, 8, 4],
    'Jurusan': ['Informatika', 'Sistem Informasi', 'Informatika', 'Data Science', 'Sistem Informasi'],
    'Predikat': ['Sangat Memuaskan', 'Cum Laude', 'Memuaskan', 'Cum Laude', 'Sangat Memuaskan']
}

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Tipe Data ===
# NIM         object
# Nama        object
# IPK        float64
# Semester     int64
# Jurusan     object
# Predikat    object
# dtype: object
#
# === Klasifikasi ===
# {'NIM': 'Nominal', 'Nama': 'Nominal', 'IPK': 'Rasio', 'Semester': 'Rasio', 'Jurusan': 'Nominal', 'Predikat': 'Ordinal'}
# ```
