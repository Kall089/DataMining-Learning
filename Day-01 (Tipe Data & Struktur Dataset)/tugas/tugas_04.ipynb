# %% [markdown]
# # Tugas 4: Filter Baris Berdasarkan Kondisi Numerik
#
# ## Deskripsi
# Dari DataFrame berikut, lakukan filtering:
# 1. Tampilkan karyawan dengan gaji > 8.000.000
# 2. Tampilkan karyawan dengan usia antara 25-35 (inklusif)
# 3. Tampilkan karyawan dengan gaji > 7.000.000 DAN usia < 30

# %%
import pandas as pd

df = pd.DataFrame({
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita', 'Hadi'],
    'Usia': [28, 35, 24, 42, 31, 26, 38, 29],
    'Gaji': [7500000, 12000000, 5500000, 15000000, 9000000, 8500000, 11000000, 6000000],
    'Divisi': ['IT', 'Finance', 'HR', 'IT', 'Marketing', 'IT', 'Finance', 'HR']
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Gaji > 8.000.000 ===
#     Nama  Usia      Gaji     Divisi
# 1   Budi    35  12000000    Finance
# 3   Dewi    42  15000000         IT
# 4    Eka    31   9000000  Marketing
# 5  Fajar    26   8500000         IT
# 6   Gita    38  11000000    Finance
#
# === Usia 25-35 ===
#     Nama  Usia      Gaji     Divisi
# 0   Andi    28   7500000         IT
# 1   Budi    35  12000000    Finance
# 4    Eka    31   9000000  Marketing
# 5  Fajar    26   8500000         IT
# 7   Hadi    29   6000000         HR
#
# === Gaji > 7jt DAN Usia < 30 ===
#     Nama  Usia     Gaji Divisi
# 0   Andi    28  7500000     IT
# 5  Fajar    26  8500000     IT
# ```
