# %% [markdown]
# # Tugas 12: Value Counts dan Proporsi
#
# ## Deskripsi
# Dari DataFrame survei berikut:
# 1. Hitung frekuensi setiap `Pendidikan` dengan `value_counts()`
# 2. Hitung proporsi (persentase) setiap `Pekerjaan` (bulatkan 2 desimal)
# 3. Tampilkan cross-tabulation antara `Pendidikan` dan `Pekerjaan`

# %%
import pandas as pd

df = pd.DataFrame({
    'Responden': [f'R{i+1:03d}' for i in range(15)],
    'Pendidikan': ['S1', 'S2', 'SMA', 'S1', 'S1', 'S2', 'SMA', 'S1',
                   'S3', 'S1', 'S2', 'SMA', 'S1', 'S2', 'S3'],
    'Pekerjaan': ['Swasta', 'PNS', 'Wiraswasta', 'PNS', 'Swasta', 'PNS',
                  'Wiraswasta', 'Swasta', 'PNS', 'Swasta', 'Swasta',
                  'Wiraswasta', 'PNS', 'Swasta', 'PNS'],
    'Penghasilan': [8000000, 12000000, 5000000, 10000000, 7500000, 13000000,
                    6000000, 9000000, 18000000, 8500000, 11000000, 4500000,
                    9500000, 14000000, 20000000]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Frekuensi Pendidikan ===
# Pendidikan
# S1     6
# S2     4
# SMA    3
# S3     2
# Name: count, dtype: int64
#
# === Proporsi Pekerjaan ===
# Pekerjaan
# Swasta        0.40
# PNS           0.40
# Wiraswasta    0.20
# Name: proportion, dtype: float64
#
# === Cross-Tabulation ===
# Pekerjaan   PNS  Swasta  Wiraswasta
# Pendidikan
# S1            2       3           1
# S2            1       2           0 (approximately - may vary)
# S3            2       0           0
# SMA           0       0           3 (approximately - may vary)
# ```
