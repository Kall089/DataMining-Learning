# %% [markdown]
# # Tugas 7: GroupBy dan Aggregasi
#
# ## Deskripsi
# Dari DataFrame penjualan berikut, lakukan:
# 1. Hitung total penjualan (`Jumlah * Harga_Satuan`) per `Kategori`
# 2. Hitung rata-rata `Jumlah` per `Kota`
# 3. Hitung jumlah transaksi (count) per `Kategori` dan `Kota`

# %%
import pandas as pd

df = pd.DataFrame({
    'Tanggal': ['2024-01-05','2024-01-05','2024-01-06','2024-01-06','2024-01-07',
                '2024-01-07','2024-01-08','2024-01-08','2024-01-09','2024-01-09',
                '2024-01-10','2024-01-10'],
    'Kota': ['Jakarta','Bandung','Jakarta','Surabaya','Bandung',
             'Surabaya','Jakarta','Bandung','Surabaya','Jakarta',
             'Bandung','Surabaya'],
    'Kategori': ['Elektronik','Makanan','Makanan','Elektronik','Elektronik',
                 'Makanan','Elektronik','Makanan','Elektronik','Makanan',
                 'Elektronik','Makanan'],
    'Jumlah': [2, 10, 5, 1, 3, 15, 4, 8, 2, 12, 1, 20],
    'Harga_Satuan': [5000000, 25000, 30000, 8000000, 3000000,
                     20000, 4500000, 15000, 6000000, 18000,
                     7000000, 22000]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Total Penjualan per Kategori ===
# Kategori
# Elektronik    47000000
# Makanan         946000
# Name: Total_Penjualan, dtype: int64
#
# === Rata-rata Jumlah per Kota ===
# Kota
# Bandung     5.50
# Jakarta     5.75
# Surabaya    9.50
# Name: Jumlah, dtype: float64
#
# === Jumlah Transaksi per Kategori & Kota ===
# Kategori    Kota
# Elektronik  Bandung      2
#             Jakarta      2
#             Surabaya     2
# Makanan     Bandung      2
#             Jakarta      2
#             Surabaya     2
# dtype: int64
# ```
