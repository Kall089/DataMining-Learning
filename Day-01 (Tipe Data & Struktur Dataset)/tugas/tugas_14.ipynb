# %% [markdown]
# # Tugas 14: Rename Kolom dan Reset Index
#
# ## Deskripsi
# Dari DataFrame berikut:
# 1. Rename kolom menggunakan dictionary mapping:
#    - `nm` → `Nama`
#    - `umr` → `Umur`
#    - `gj` → `Gaji`
#    - `div` → `Divisi`
# 2. Filter hanya karyawan divisi 'IT', lalu reset index
# 3. Tampilkan DataFrame setelah rename dan setelah reset index

# %%
import pandas as pd

df = pd.DataFrame({
    'nm': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita', 'Hadi'],
    'umr': [28, 35, 24, 42, 31, 26, 38, 29],
    'gj': [7500000, 12000000, 5500000, 15000000, 9000000, 8500000, 11000000, 6000000],
    'div': ['IT', 'Finance', 'HR', 'IT', 'Marketing', 'IT', 'Finance', 'HR']
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Setelah Rename ===
#     Nama  Umur      Gaji     Divisi
# 0   Andi    28   7500000         IT
# 1   Budi    35  12000000    Finance
# 2  Citra    24   5500000         HR
# 3   Dewi    42  15000000         IT
# 4    Eka    31   9000000  Marketing
# 5  Fajar    26   8500000         IT
# 6   Gita    38  11000000    Finance
# 7   Hadi    29   6000000         HR
#
# === Filter IT + Reset Index ===
#     Nama  Umur      Gaji Divisi
# 0   Andi    28   7500000     IT
# 1   Dewi    42  15000000     IT
# 2  Fajar    26   8500000     IT
# ```
