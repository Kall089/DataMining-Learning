# %% [markdown]
# # Tugas 5: Filter Baris Berdasarkan Kondisi String
#
# ## Deskripsi
# Dari DataFrame berikut, lakukan filtering berbasis string:
# 1. Tampilkan buku dengan genre 'Fiksi'
# 2. Tampilkan buku yang judulnya mengandung kata 'Data' (case-insensitive)
# 3. Tampilkan buku dengan penerbit yang dimulai huruf 'G'

# %%
import pandas as pd

df = pd.DataFrame({
    'Judul': ['Data Science Handbook', 'Laskar Pelangi', 'Intro to Data Mining',
              'Bumi Manusia', 'Big Data Analytics', 'Filosofi Teras', 'Deep Learning'],
    'Penulis': ['Jake VanderPlas', 'Andrea Hirata', 'Pang-Ning Tan',
                'Pramoedya', 'Foster Provost', 'Henry Manampiring', 'Ian Goodfellow'],
    'Genre': ['Sains', 'Fiksi', 'Sains', 'Fiksi', 'Sains', 'Self-Help', 'Sains'],
    'Penerbit': ['OReilly', 'Bentang', 'Pearson', 'Grafiti', 'OReilly', 'Gramedia', 'MIT Press'],
    'Harga': [450000, 89000, 520000, 95000, 480000, 78000, 610000]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Genre Fiksi ===
#            Judul        Penulis Genre Penerbit  Harga
# 1  Laskar Pelangi  Andrea Hirata  Fiksi  Bentang  89000
# 3   Bumi Manusia      Pramoedya  Fiksi  Grafiti  95000
#
# === Judul mengandung 'Data' ===
#                    Judul         Penulis  Genre Penerbit   Harga
# 0  Data Science Handbook  Jake VanderPlas  Sains  OReilly  450000
# 2   Intro to Data Mining   Pang-Ning Tan  Sains  Pearson  520000
# 4     Big Data Analytics  Foster Provost  Sains  OReilly  480000
#
# === Penerbit dimulai 'G' ===
#             Judul            Penulis    Genre Penerbit  Harga
# 3    Bumi Manusia          Pramoedya    Fiksi  Grafiti  95000
# 5  Filosofi Teras  Henry Manampiring  Self-Help  Gramedia  78000
# ```
