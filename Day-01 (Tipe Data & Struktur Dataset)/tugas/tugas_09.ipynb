# %% [markdown]
# # Tugas 9: Mengubah Tipe Data Kolom
#
# ## Deskripsi
# DataFrame berikut memiliki tipe data yang tidak sesuai.
# Lakukan konversi:
# 1. Ubah `Harga` dari string ke float (hapus 'Rp' dan '.')
# 2. Ubah `Tanggal` dari string ke datetime
# 3. Ubah `Stok` dari float ke int
# 4. Ubah `Tersedia` dari string ('Ya'/'Tidak') ke boolean
# 5. Tampilkan `.dtypes` sebelum dan sesudah konversi

# %%
import pandas as pd

df = pd.DataFrame({
    'Produk': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headset'],
    'Harga': ['Rp12.000.000', 'Rp150.000', 'Rp350.000', 'Rp3.500.000', 'Rp450.000'],
    'Tanggal': ['2024-01-15', '2024-02-20', '2024-01-30', '2024-03-10', '2024-02-05'],
    'Stok': [15.0, 200.0, 120.0, 30.0, 80.0],
    'Tersedia': ['Ya', 'Ya', 'Tidak', 'Ya', 'Tidak']
})

print('=== SEBELUM ===')
print(df.dtypes)

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === SEBELUM ===
# Produk       object
# Harga        object
# Tanggal      object
# Stok        float64
# Tersedia     object
# dtype: object
#
# === SESUDAH ===
# Produk              object
# Harga              float64
# Tanggal     datetime64[ns]
# Stok                 int64
# Tersedia              bool
# dtype: object
#
# === DataFrame ===
#     Produk       Harga    Tanggal  Stok  Tersedia
# 0   Laptop  12000000.0 2024-01-15    15      True
# 1    Mouse    150000.0 2024-02-20   200      True
# 2  Keyboard   350000.0 2024-01-30   120     False
# 3  Monitor   3500000.0 2024-03-10    30      True
# 4  Headset    450000.0 2024-02-05    80     False
# ```
