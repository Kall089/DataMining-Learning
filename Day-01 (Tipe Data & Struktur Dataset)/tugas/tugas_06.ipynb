# %% [markdown]
# # Tugas 6: Statistik Deskriptif Kolom Numerik
#
# ## Deskripsi
# Dari DataFrame berikut, hitung:
# 1. `.describe()` untuk semua kolom numerik
# 2. Mean, Median, dan Std dari kolom `Nilai`
# 3. Min dan Max dari kolom `Waktu_Menit`

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df = pd.DataFrame({
    'Siswa': [f'Siswa_{i+1}' for i in range(20)],
    'Nilai': [78, 85, 92, 64, 71, 88, 95, 55, 83, 76,
              90, 67, 73, 81, 96, 59, 87, 74, 91, 68],
    'Waktu_Menit': [45, 38, 30, 55, 48, 35, 25, 60, 40, 47,
                    32, 52, 46, 42, 28, 58, 36, 44, 31, 50],
    'Kelas': ['A','B','A','B','A','B','A','B','A','B',
              'A','B','A','B','A','B','A','B','A','B']
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Describe ===
#            Nilai  Waktu_Menit
# count  20.000000    20.000000
# mean   78.650000    42.100000
# std    11.994151    10.203431
# min    55.000000    25.000000
# 25%    70.250000    33.250000
# 50%    79.500000    43.000000
# 75%    89.500000    49.250000
# max    96.000000    60.000000
#
# === Statistik Nilai ===
# Mean  : 78.65
# Median: 79.5
# Std   : 11.99
#
# === Min/Max Waktu ===
# Min: 25 menit
# Max: 60 menit
# ```
