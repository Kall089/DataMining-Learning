# %% [markdown]
# # Tugas 8: Menambah Kolom Baru (Calculated Column)
#
# ## Deskripsi
# Dari DataFrame berikut, tambahkan kolom baru:
# 1. `BMI` = Berat / (Tinggi/100)^2 (bulatkan 2 desimal)
# 2. `Kategori_BMI` berdasarkan:
#    - BMI < 18.5 → 'Underweight'
#    - 18.5 <= BMI < 25 → 'Normal'
#    - 25 <= BMI < 30 → 'Overweight'
#    - BMI >= 30 → 'Obese'
# 3. Tampilkan DataFrame lengkap

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita', 'Hadi'],
    'Tinggi': [175, 168, 160, 155, 180, 172, 158, 190],
    'Berat': [70, 85, 48, 52, 95, 68, 45, 110]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
#     Nama  Tinggi  Berat    BMI Kategori_BMI
# 0   Andi     175     70  22.86       Normal
# 1   Budi     168     85  30.12        Obese
# 2  Citra     160     48  18.75       Normal
# 3   Dewi     155     52  21.64       Normal
# 4    Eka     180     95  29.32   Overweight
# 5  Fajar     172     68  22.99       Normal
# 6   Gita     158     45  18.03  Underweight
# 7   Hadi     190    110  30.47        Obese
# ```
