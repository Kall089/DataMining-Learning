# %% [markdown]
# # Tugas 2: Membuat DataFrame dari Dictionary
#
# ## Deskripsi
# Buatlah DataFrame dari data penjualan toko berikut, lalu:
# 1. Tampilkan 3 baris pertama dengan `.head(3)`
# 2. Tampilkan dimensi DataFrame dengan `.shape`
# 3. Tampilkan info ringkasan dengan `.info()`

# %%
import pandas as pd

data_penjualan = {
    'Produk': ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headset', 'Webcam', 'SSD'],
    'Harga': [12000000, 150000, 350000, 3500000, 450000, 800000, 950000],
    'Stok': [15, 200, 120, 30, 80, 50, 65],
    'Kategori': ['Komputer', 'Aksesoris', 'Aksesoris', 'Komputer', 'Audio', 'Aksesoris', 'Storage'],
    'Rating': [4.5, 4.2, 4.0, 4.7, 3.8, 4.1, 4.6]
}

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === 3 Baris Pertama ===
#     Produk     Harga  Stok  Kategori  Rating
# 0   Laptop  12000000    15  Komputer     4.5
# 1    Mouse    150000   200  Aksesoris    4.2
# 2  Keyboard   350000   120  Aksesoris    4.0
#
# === Dimensi ===
# (7, 5)
#
# === Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Produk    7 non-null      object
#  1   Harga     7 non-null      int64
#  2   Stok      7 non-null      int64
#  3   Kategori  7 non-null      object
#  4   Rating    7 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# ```
