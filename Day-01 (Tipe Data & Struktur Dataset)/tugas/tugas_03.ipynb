# %% [markdown]
# # Tugas 3: Membuat DataFrame dari List of Lists
#
# ## Deskripsi
# Diberikan data dalam bentuk list of lists dan daftar nama kolom.
# Buatlah DataFrame, lalu:
# 1. Set kolom `ID` sebagai index
# 2. Tampilkan DataFrame setelah di-set index
# 3. Tampilkan nama-nama kolom yang tersisa

# %%
import pandas as pd

kolom = ['ID', 'Kota', 'Populasi', 'Luas_km2', 'Provinsi']
data = [
    [1, 'Jakarta', 10560000, 662, 'DKI Jakarta'],
    [2, 'Surabaya', 2874000, 350, 'Jawa Timur'],
    [3, 'Bandung', 2444000, 168, 'Jawa Barat'],
    [4, 'Medan', 2210000, 265, 'Sumatera Utara'],
    [5, 'Semarang', 1653000, 374, 'Jawa Tengah']
]

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === DataFrame dengan Index ID ===
#         Kota  Populasi  Luas_km2        Provinsi
# ID
# 1    Jakarta  10560000       662     DKI Jakarta
# 2   Surabaya   2874000       350      Jawa Timur
# 3    Bandung   2444000       168      Jawa Barat
# 4      Medan   2210000       265  Sumatera Utara
# 5   Semarang   1653000       374    Jawa Tengah
#
# === Kolom yang tersisa ===
# Index(['Kota', 'Populasi', 'Luas_km2', 'Provinsi'], dtype='object')
# ```
