# %% [markdown]
# # Tugas 10: Sorting DataFrame Multi-Kolom
#
# ## Deskripsi
# Dari DataFrame berikut, lakukan sorting:
# 1. Sort berdasarkan `Nilai` descending
# 2. Sort berdasarkan `Kelas` ascending, lalu `Nilai` descending
# 3. Tampilkan 5 siswa dengan nilai tertinggi

# %%
import pandas as pd

df = pd.DataFrame({
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita', 'Hadi', 'Indah', 'Joko'],
    'Kelas': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Nilai': [85, 92, 78, 88, 95, 73, 91, 80, 87, 96],
    'Absensi': [2, 0, 3, 1, 0, 4, 1, 2, 1, 0]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Sort Nilai Descending ===
#     Nama Kelas  Nilai  Absensi
# 9   Joko     B     96        0
# 4    Eka     A     95        0
# 1   Budi     B     92        0
# 6   Gita     A     91        1
# 3   Dewi     B     88        1
# 8  Indah     A     87        1
# 0   Andi     A     85        2
# 7   Hadi     B     80        2
# 2  Citra     A     78        3
# 5  Fajar     B     73        4
#
# === Sort Kelas ASC, Nilai DESC ===
#     Nama Kelas  Nilai  Absensi
# 4    Eka     A     95        0
# 6   Gita     A     91        1
# 8  Indah     A     87        1
# 0   Andi     A     85        2
# 2  Citra     A     78        3
# 9   Joko     B     96        0
# 1   Budi     B     92        0
# 3   Dewi     B     88        1
# 7   Hadi     B     80        2
# 5  Fajar     B     73        4
#
# === Top 5 Nilai Tertinggi ===
#    Nama Kelas  Nilai  Absensi
# 9  Joko     B     96        0
# 4   Eka     A     95        0
# 1  Budi     B     92        0
# 6  Gita     A     91        1
# 3  Dewi     B     88        1
# ```
