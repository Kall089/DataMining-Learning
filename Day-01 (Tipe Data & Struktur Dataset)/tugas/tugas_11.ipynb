# %% [markdown]
# # Tugas 11: Menghitung Missing Values
#
# ## Deskripsi
# DataFrame berikut memiliki missing values (NaN).
# Lakukan:
# 1. Hitung jumlah missing values per kolom
# 2. Hitung persentase missing values per kolom (bulatkan 2 desimal)
# 3. Tampilkan hanya kolom yang memiliki missing values

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita', 'Hadi', 'Indah', 'Joko'],
    'Usia': [28, np.nan, 24, 42, 31, np.nan, 38, 29, np.nan, 35],
    'Gaji': [7500000, 12000000, np.nan, 15000000, 9000000, 8500000, np.nan, 6000000, 7000000, np.nan],
    'Email': ['andi@mail.com', 'budi@mail.com', None, 'dewi@mail.com', None,
              'fajar@mail.com', 'gita@mail.com', None, 'indah@mail.com', 'joko@mail.com'],
    'Divisi': ['IT', 'Finance', 'HR', 'IT', 'Marketing', 'IT', 'Finance', 'HR', 'IT', 'Marketing']
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Jumlah Missing Values ===
# Nama      0
# Usia      3
# Gaji      3
# Email     3
# Divisi    0
# dtype: int64
#
# === Persentase Missing Values ===
# Nama       0.0
# Usia      30.0
# Gaji      30.0
# Email     30.0
# Divisi     0.0
# dtype: float64
#
# === Kolom dengan Missing Values ===
# Usia     3
# Gaji     3
# Email    3
# dtype: int64
# ```
