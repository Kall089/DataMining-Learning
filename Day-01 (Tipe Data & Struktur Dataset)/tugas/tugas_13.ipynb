# %% [markdown]
# # Tugas 13: Slicing DataFrame dengan iloc dan loc
#
# ## Deskripsi
# Dari DataFrame berikut, lakukan slicing:
# 1. Ambil baris ke-2 sampai ke-5 menggunakan `iloc`
# 2. Ambil kolom `Nama` dan `Nilai_UAS` untuk semua baris menggunakan `loc`
# 3. Ambil baris ke-0, 3, 6 dan kolom ke-0, 2, 4 menggunakan `iloc`
# 4. Ambil baris dengan `Nama` dari 'Citra' sampai 'Gita' menggunakan `loc` (set Nama sebagai index dulu)

# %%
import pandas as pd

df = pd.DataFrame({
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita', 'Hadi'],
    'Nilai_UTS': [78, 85, 92, 64, 71, 88, 95, 55],
    'Nilai_UAS': [82, 90, 88, 70, 75, 91, 93, 60],
    'Tugas': [80, 88, 85, 72, 78, 90, 92, 65],
    'Kehadiran': [90, 95, 100, 85, 88, 92, 98, 80]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === 1. iloc baris 2-5 ===
#     Nama  Nilai_UTS  Nilai_UAS  Tugas  Kehadiran
# 2  Citra         92         88     85        100
# 3   Dewi         64         70     72         85
# 4    Eka         71         75     78         88
# 5  Fajar         88         91     90         92
#
# === 2. loc kolom Nama dan Nilai_UAS ===
#     Nama  Nilai_UAS
# 0   Andi         82
# 1   Budi         90
# 2  Citra         88
# 3   Dewi         70
# 4    Eka         75
# 5  Fajar         91
# 6   Gita         93
# 7   Hadi         60
#
# === 3. iloc baris [0,3,6] kolom [0,2,4] ===
#    Nama  Nilai_UAS  Kehadiran
# 0  Andi         82         90
# 3  Dewi         70         85
# 6  Gita         93         98
#
# === 4. loc Citra sampai Gita ===
#        Nilai_UTS  Nilai_UAS  Tugas  Kehadiran
# Nama
# Citra         92         88     85        100
# Dewi          64         70     72         85
# Eka           71         75     78         88
# Fajar         88         91     90         92
# Gita          95         93     92         98
# ```
