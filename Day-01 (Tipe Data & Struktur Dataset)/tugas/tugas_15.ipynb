# %% [markdown]
# # Tugas 15: Merge / Join Dua DataFrame
#
# ## Deskripsi
# Diberikan dua DataFrame: `df_siswa` dan `df_nilai`.
# Lakukan:
# 1. **Inner join** berdasarkan kolom `NIS`
# 2. **Left join** berdasarkan kolom `NIS`
# 3. Setelah left join, tampilkan siswa yang **tidak memiliki nilai** (NaN di kolom Nilai)

# %%
import pandas as pd
import numpy as np

df_siswa = pd.DataFrame({
    'NIS': ['S001', 'S002', 'S003', 'S004', 'S005', 'S006', 'S007'],
    'Nama': ['Andi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar', 'Gita'],
    'Kelas': ['X-A', 'X-B', 'X-A', 'X-B', 'X-A', 'X-B', 'X-A']
})

df_nilai = pd.DataFrame({
    'NIS': ['S001', 'S002', 'S003', 'S005', 'S008'],
    'Matematika': [85, 92, 78, 88, 90],
    'Fisika': [80, 88, 82, 91, 85],
    'Kimia': [75, 95, 80, 87, 92]
})

# %%
# TODO: Kerjakan di sini

# %% [markdown]
# ## Expected Output
# ```
# === Inner Join ===
#     NIS   Nama Kelas  Matematika  Fisika  Kimia
# 0  S001   Andi   X-A          85      80     75
# 1  S002   Budi   X-B          92      88     95
# 2  S003  Citra   X-A          78      82     80
# 3  S005    Eka   X-A          88      91     87
#
# === Left Join ===
#     NIS   Nama Kelas  Matematika  Fisika  Kimia
# 0  S001   Andi   X-A       85.0    80.0   75.0
# 1  S002   Budi   X-B       92.0    88.0   95.0
# 2  S003  Citra   X-A       78.0    82.0   80.0
# 3  S004   Dewi   X-B        NaN     NaN    NaN
# 4  S005    Eka   X-A       88.0    91.0   87.0
# 5  S006  Fajar   X-B        NaN     NaN    NaN
# 6  S007   Gita   X-A        NaN     NaN    NaN
#
# === Siswa Tanpa Nilai ===
#     NIS   Nama Kelas  Matematika  Fisika  Kimia
# 3  S004   Dewi   X-B        NaN     NaN    NaN
# 5  S006  Fajar   X-B        NaN     NaN    NaN
# 6  S007   Gita   X-A        NaN     NaN    NaN
# ```
