# %% [markdown]
# # 🏋️ Exercise 4: Deteksi Inkonsistensi Data
#
# **Day**: 1 | **Difficulty**: Medium
# **Topic**: Data Quality, Inconsistency Detection, .str operations
#
# ---
#
# ## 📋 Problem Statement
#
# Kamu menerima dataset survei kepuasan pelanggan yang dikumpulkan dari berbagai channel (web, mobile, telepon). Karena dikumpulkan dari banyak tempat, datanya **penuh inkonsistensi**: format tidak seragam, tipe data salah, nilai yang sama ditulis berbeda-beda.
#
# Sebelum data bisa dipakai, kamu perlu **mendeteksi dan mendokumentasikan** semua masalah. Ingat: langkah pertama cleaning adalah **deteksi** — pahami dulu sebelum bersihkan.
#
# ## 🎯 Learning Goals
# - Mendeteksi inkonsistensi format dan nilai
# - Menggunakan `.str` accessor untuk analisis teks
# - Mengidentifikasi masalah tipe data
# - Mendokumentasikan masalah data secara sistematis

# %%
import numpy as np
import pandas as pd

# Dataset survei yang penuh inkonsistensi
data_kotor = {
    'id':            ['S001','S002','S003','S004','S005','S006','S007','S008','S009','S010'],
    'nama':          ['Andi','BUDI SANTOSO','citra','Dian Pratama','  Eko  ','Fani','GITA SARI','hendra','Indah','Joko'],
    'umur':          ['28','45','tiga puluh','52','19','35','41','28',None,'55'],
    'jenis_kelamin': ['L','Laki-laki','P','male','female','L','Perempuan','laki','p','M'],
    'rating':        [5,'4',3,'lima',4,'5',3,4,'2',5],
    'email':         ['andi@gmail.com','budi@yahoo','citra@hotmail.com','dian@gmail.com',
                      'eko.gmail.com','fani@gmail.com','gita@company.co.id',
                      'hendra@gmail.com','indah@outlook.com','joko@gov.go.id'],
    'pendapatan':    ['Rp 5.000.000','8000000','Rp8,500,000','12.000.000','3500000',
                      'Rp 9.500.000','7000000','Rp 4.250.000','6500000','15000000'],
    'kepuasan':      ['sangat puas','Puas','BIASA','puas','sangat puas','tidak puas','Biasa','PUAS','sangat tidak puas','Puas'],
}

df = pd.DataFrame(data_kotor)
print('Dataset Survei (bermasalah):')
display(df)
print()
print('Tipe data:')
print(df.dtypes)

# %%
# ============================================================
# TODO 1: Identifikasi semua kolom yang memiliki masalah
#
# Untuk setiap kolom, cek:
# a. Apakah ada missing value? (isnull)
# b. Apakah ada inkonsistensi nilai? (value_counts)
# c. Apakah tipe data sudah benar?
#
# Lakukan analisis satu per satu, lalu buat daftar masalah.
# Expected output: Analisis per kolom yang bermasalah
# ============================================================

print('=== Analisis Missing Values ===')
# TODO: cetak isnull().sum()

print()
print('=== Value counts kolom jenis_kelamin ===')
# TODO: cetak value_counts untuk jenis_kelamin
# Berapa versi berbeda yang ada?

print()
print('=== Value counts kolom kepuasan ===')
# TODO: cetak value_counts untuk kepuasan
# Ada berapa kategori unik yang seharusnya cuma 5?

# %%
# ============================================================
# TODO 2: Deteksi email yang tidak valid
#
# Email valid harus mengandung '@' dan minimal satu '.' setelah '@'
# Gunakan .str.contains() untuk mendeteksi yang tidak valid
#
# Expected output: List email yang tidak valid beserta ID-nya
# ============================================================

# TODO: Buat mask untuk email yang TIDAK VALID
# Hint: email valid = punya '@' DAN (bagian setelah '@' punya '.')
# Hint: df['email'].str.contains(pattern)

# mask_tidak_valid = ...
# print('Email tidak valid:')
# print(df[mask_tidak_valid][['id','email']])

print('Email tidak valid:')
# TODO

# %%
# ============================================================
# TODO 3: Deteksi nilai 'umur' yang tidak bisa dikonversi ke angka
#
# Gunakan pd.to_numeric(errors='coerce') — nilai yang tidak bisa
# dikonversi akan menjadi NaN.
# Tampilkan baris mana yang umurnya bermasalah.
#
# Expected output: Baris dengan umur tidak valid + nilai aslinya
# ============================================================

# TODO: Konversi umur dengan errors='coerce', cek mana yang NaN
# umur_converted = pd.to_numeric(df['umur'], errors='coerce')
# mask_umur_error = umur_converted.isnull()

print('Baris dengan umur bermasalah:')
# TODO

# %%
# ============================================================
# TODO 4: Buat laporan masalah data (Data Quality Report)
#
# Buat DataFrame ringkasan dengan kolom:
# - 'kolom': nama kolom
# - 'masalah': deskripsi masalah (string)
# - 'jumlah_baris_bermasalah': int
# - 'persentase': float
#
# Isi setidaknya 5 masalah yang kamu temukan.
# ============================================================

laporan = pd.DataFrame({
    'kolom': [
        # TODO: isi nama kolom yang bermasalah
    ],
    'masalah': [
        # TODO: deskripsi masalah
    ],
    'jumlah_baris_bermasalah': [
        # TODO: hitungan
    ],
    'persentase': [
        # TODO: persen dari total baris
    ],
})

print('Data Quality Report:')
display(laporan)

# %% [markdown]
# **💡 Hint TODO 2**: Pola email yang valid: `r'@.*\.'` — harus ada `@` diikuti karakter lalu `.`
#
# **💡 Hint TODO 4**: Hitung masalah per kolom dari analisis sebelumnya, lalu buat DataFrame manual.
#
# ---
# ## 🤔 Pertanyaan Refleksi
#
# 1. Dari semua masalah yang kamu temukan, mana yang paling berbahaya jika tidak diperbaiki sebelum modeling?
# 2. Kolom `pendapatan` punya format berbeda-beda. Langkah apa yang perlu dilakukan untuk menyeragamkannya?
# 3. Apakah inkonsistensi kapitalisasi pada `nama` dan `kepuasan` perlu diperbaiki? Mengapa?
