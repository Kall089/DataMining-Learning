# %% [markdown]
# # 🏋️ Exercise 1: Identifikasi Tipe Data
#
# **Day**: 1 | **Difficulty**: Easy
# **Topic**: Nominal, Ordinal, Discrete, Continuous
#
# ---
#
# ## 📋 Problem Statement
#
# Kamu bekerja sebagai data analyst di sebuah platform e-commerce. Tim kamu baru saja menerima dataset transaksi pelanggan dan kamu diminta untuk **mengidentifikasi tipe data** setiap kolom sebelum tim engineering memulai preprocessing.
#
# Identifikasi yang benar sangat penting karena:
# - Kolom **nominal** perlu one-hot encoding
# - Kolom **ordinal** perlu ordinal encoding dengan urutan yang benar
# - Kolom **numerik** perlu scaling atau normalisasi
#
# Kesalahan identifikasi tipe data = preprocessing yang salah = model yang buruk.
#
# ## 🎯 Learning Goals
# - Membedakan nominal vs ordinal vs discrete vs continuous
# - Menggunakan domain knowledge (bukan hanya dtypes) untuk identifikasi
# - Memahami mengapa tipe data penting untuk preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns

np.random.seed(42)

# Dataset transaksi e-commerce
data_ecommerce = {
    'order_id':          ['ORD-001', 'ORD-002', 'ORD-003', 'ORD-004', 'ORD-005', 'ORD-006', 'ORD-007', 'ORD-008'],
    'kategori_produk':   ['elektronik', 'fashion', 'makanan', 'elektronik', 'fashion', 'makanan', 'elektronik', 'fashion'],
    'harga_produk':      [1250000.0, 350000.0, 85000.0, 3200000.0, 125000.0, 45000.0, 875000.0, 290000.0],
    'jumlah_item':       [1, 2, 5, 1, 3, 10, 1, 2],
    'rating_penjual':    [4, 5, 3, 5, 4, 2, 5, 3],
    'status_pengiriman': ['terkirim', 'proses', 'terkirim', 'terkirim', 'proses', 'terkirim', 'proses', 'terkirim'],
    'metode_bayar':      ['transfer', 'qris', 'cod', 'transfer', 'qris', 'cod', 'transfer', 'qris'],
    'berat_paket_kg':    [0.5, 1.2, 2.8, 0.3, 0.8, 5.0, 0.4, 1.5],
    'kode_pos_tujuan':   [12345, 60111, 40115, 10110, 50132, 80117, 30123, 70219],
    'sudah_review':      [True, False, True, True, False, True, False, True],
    'prioritas_ongkir':  ['reguler', 'express', 'same-day', 'reguler', 'express', 'reguler', 'same-day', 'express'],
    'diskon_persen':     [0, 10, 0, 20, 5, 0, 15, 10],
}

df = pd.DataFrame(data_ecommerce)
print('Dataset E-Commerce Transaksi:')
display(df)
print()
print('Tipe data menurut Pandas:')
print(df.dtypes)

# %% [markdown]
# ---
# ## 📝 Langkah Pengerjaan
#
# 1. Analisis setiap kolom berdasarkan domain knowledge (bukan hanya dtypes)
# 2. Tentukan tipe data: Nominal / Ordinal / Discrete / Continuous
# 3. Jelaskan alasan untuk kolom-kolom yang tidak obvious
# 4. Identifikasi kolom yang "menipu" (terlihat numerik tapi sebenarnya nominal)

# %%
# ============================================================
# TODO 1: Lengkapi tabel klasifikasi tipe data di bawah ini
#
# Instruksi:
# - Isi kolom 'tipe_data' dengan salah satu:
#   'Nominal', 'Ordinal', 'Discrete', atau 'Continuous'
# - Isi 'alasan' dengan penjelasan singkat mengapa
#
# Expected output: DataFrame dengan klasifikasi yang benar
# ============================================================

klasifikasi = {
    'kolom': [
        'order_id', 'kategori_produk', 'harga_produk', 'jumlah_item',
        'rating_penjual', 'status_pengiriman', 'metode_bayar',
        'berat_paket_kg', 'kode_pos_tujuan', 'sudah_review',
        'prioritas_ongkir', 'diskon_persen'
    ],
    'tipe_data': [
        '???',  # order_id
        '???',  # kategori_produk
        '???',  # harga_produk
        '???',  # jumlah_item
        '???',  # rating_penjual
        '???',  # status_pengiriman
        '???',  # metode_bayar
        '???',  # berat_paket_kg
        '???',  # kode_pos_tujuan
        '???',  # sudah_review
        '???',  # prioritas_ongkir
        '???',  # diskon_persen
    ],
    'alasan': [
        'Tulis alasanmu di sini',  # order_id
        'Tulis alasanmu di sini',  # kategori_produk
        'Tulis alasanmu di sini',  # harga_produk
        'Tulis alasanmu di sini',  # jumlah_item
        'Tulis alasanmu di sini',  # rating_penjual
        'Tulis alasanmu di sini',  # status_pengiriman
        'Tulis alasanmu di sini',  # metode_bayar
        'Tulis alasanmu di sini',  # berat_paket_kg
        'Tulis alasanmu di sini',  # kode_pos_tujuan
        'Tulis alasanmu di sini',  # sudah_review
        'Tulis alasanmu di sini',  # prioritas_ongkir
        'Tulis alasanmu di sini',  # diskon_persen
    ]
}

df_klasifikasi = pd.DataFrame(klasifikasi)
df_klasifikasi

# %% [markdown]
# **💡 Hint**: Perhatikan kolom `kode_pos_tujuan`, `rating_penjual`, dan `diskon_persen` — semuanya berupa angka, tapi apakah semuanya numerik dalam arti statistik?

# %%
# ============================================================
# TODO 2: Identifikasi kolom yang "menipu"
#
# Beberapa kolom terlihat numerik (int/float) di Pandas
# tapi sebenarnya bukan numerik dalam konteks statistik.
#
# Tugas: Buat list berisi nama kolom yang "menipu" tersebut
# dan jelaskan mengapa mereka bukan numerik sesungguhnya.
#
# Expected output: list dengan minimal 2 kolom yang menipu
# ============================================================

kolom_menipu = []  # Isi dengan nama kolom yang menipu
penjelasan   = {}  # {'nama_kolom': 'penjelasan kenapa menipu'}

print('Kolom yang menipu:', kolom_menipu)
for k, p in penjelasan.items():
    print(f'  {k}: {p}')

# %%
# ============================================================
# TODO 3: Untuk kolom ordinal, tentukan urutan yang benar
#
# Dataset ini punya 2 kolom ordinal.
# Buat dictionary dengan key = nama kolom ordinal,
# value = list nilai dalam urutan DARI TERKECIL ke TERBESAR
#
# Expected output:
# {'nama_kolom': ['nilai_terkecil', ..., 'nilai_terbesar'], ...}
# ============================================================

urutan_ordinal = {
    # Contoh format:
    # 'nama_kolom': ['nilai1', 'nilai2', 'nilai3'],
}

print('Urutan Ordinal yang Benar:')
for kolom, urutan in urutan_ordinal.items():
    print(f'  {kolom}: {urutan}')

# %% [markdown]
# ---
# ## 🤔 Pertanyaan Refleksi
#
# 1. Mengapa `kode_pos_tujuan` tidak boleh diperlakukan sebagai numerik meskipun berupa angka?
# 2. Kalau kamu harus memilih model ML yang sensitif terhadap jarak (misalnya KNN), kolom mana yang **wajib** di-scaling?
# 3. Apakah `diskon_persen` (0%, 5%, 10%, 15%, 20%) bisa dianggap ordinal? Bisa dianggap numerik? Jelaskan!
#
# *Tulis jawabanmu di markdown cell baru di bawah ini:*
