# %% [markdown]
# # 🏋️ Exercise 2: Membuat DataFrame dari Berbagai Sumber
#
# **Day**: 1 | **Difficulty**: Easy
# **Topic**: Pandas DataFrame Creation, Basic Operations
#
# ---
#
# ## 📋 Problem Statement
#
# Kamu adalah data engineer baru di sebuah startup kesehatan. Data dari berbagai sumber masuk ke tim kamu dalam berbagai format: ada yang dari sistem lama berupa dictionary Python, ada yang dari Google Forms berupa list, ada yang dari database berupa CSV string, dan ada yang butuh di-generate secara sintetis untuk testing.
#
# Tugasmu adalah membuat Pandas DataFrame dari keempat sumber tersebut, memastikan tipe data sudah benar, dan melakukan operasi dasar untuk memvalidasi datanya.
#
# ## 🎯 Learning Goals
# - Membuat DataFrame dari dictionary, list of dicts, CSV string
# - Menambahkan kolom baru ke DataFrame
# - Menggabungkan dua DataFrame (pd.concat)
# - Menyimpan dan membaca DataFrame sebagai CSV

# %%
import numpy as np
import pandas as pd
from io import StringIO

np.random.seed(42)
print('Setup selesai!')

# %% [markdown]
# ---
# ## 📝 Sumber Data yang Tersedia

# %%
# Sumber 1: Data pasien dari sistem lama (dictionary)
data_pasien_lama = {
    'id_pasien':  ['P001', 'P002', 'P003', 'P004', 'P005'],
    'nama':       ['Andi Wijaya', 'Budi Santoso', 'Citra Dewi', 'Dian Pratama', 'Eko Suryadi'],
    'umur':       [28, 45, 33, 52, 19],
    'berat_kg':   [65.5, 78.0, 55.2, 82.3, 60.0],
    'goldar':     ['A', 'O', 'B', 'AB', 'O'],
}

# Sumber 2: Data pemeriksaan dari Google Forms (list of dicts)
data_pemeriksaan = [
    {'id_pasien': 'P001', 'tekanan_darah': '120/80', 'kolesterol': 185, 'diabetes': False},
    {'id_pasien': 'P002', 'tekanan_darah': '140/90', 'kolesterol': 240, 'diabetes': True},
    {'id_pasien': 'P003', 'tekanan_darah': '110/70', 'kolesterol': 170, 'diabetes': False},
    {'id_pasien': 'P004', 'tekanan_darah': '160/100','kolesterol': 280, 'diabetes': True},
    {'id_pasien': 'P005', 'tekanan_darah': '115/75', 'kolesterol': 165, 'diabetes': False},
]

# Sumber 3: Data obat dari database (CSV string)
csv_obat = """id_pasien,nama_obat,dosis_mg,frekuensi_hari
P002,Metformin,500,2
P004,Metformin,1000,2
P004,Amlodipine,5,1
P002,Atorvastatin,20,1"""

print('Sumber data sudah tersedia!')
print(f'  Pasien lama : {len(data_pasien_lama["id_pasien"])} record')
print(f'  Pemeriksaan : {len(data_pemeriksaan)} record')
print(f'  Obat (CSV)  : 4 record')

# %%
# ============================================================
# TODO 1: Buat DataFrame dari setiap sumber data
#
# Instruksi:
# - df_pasien   : buat dari data_pasien_lama (dictionary)
# - df_periksa  : buat dari data_pemeriksaan (list of dicts)
# - df_obat     : buat dari csv_obat (gunakan StringIO)
#
# Expected output: 3 DataFrame yang sudah terisi
# ============================================================

df_pasien  = None  # TODO: buat dari data_pasien_lama
df_periksa = None  # TODO: buat dari data_pemeriksaan
df_obat    = None  # TODO: buat dari csv_obat dengan StringIO

print('df_pasien:')
display(df_pasien)
print('df_periksa:')
display(df_periksa)
print('df_obat:')
display(df_obat)

# %%
# ============================================================
# TODO 2: Tambahkan kolom 'bmi' ke df_pasien
#
# Rumus BMI = berat_kg / (tinggi_m ** 2)
# Kita tidak punya tinggi, jadi generate sintetis:
# tinggi_m = [1.72, 1.68, 1.60, 1.75, 1.65]
#
# Juga tambahkan kolom 'kategori_bmi' berdasarkan:
#   BMI < 18.5  → 'Kurus'
#   18.5 - 24.9 → 'Normal'
#   25 - 29.9   → 'Overweight'
#   >= 30       → 'Obesitas'
#
# Expected output: df_pasien dengan kolom tambahan 'bmi' dan 'kategori_bmi'
# ============================================================

tinggi_m = [1.72, 1.68, 1.60, 1.75, 1.65]

# TODO: Hitung BMI dan tambahkan ke df_pasien
# TODO: Tentukan kategori_bmi dan tambahkan ke df_pasien

print('df_pasien dengan BMI:')
display(df_pasien)

# %%
# ============================================================
# TODO 3: Gabungkan df_pasien dan df_periksa berdasarkan id_pasien
#
# Gunakan pd.merge() dengan how='inner' dan on='id_pasien'
# Hasilnya simpan ke df_gabung
#
# Expected output: DataFrame dengan 5 baris, kolom dari kedua sumber
# ============================================================

df_gabung = None  # TODO: merge df_pasien dan df_periksa

print('df_gabung (pasien + pemeriksaan):')
display(df_gabung)

# %%
# ============================================================
# TODO 4: Simpan df_gabung ke CSV dan baca kembali
#
# Simpan ke file 'hasil_pasien.csv' (tanpa index)
# Baca kembali ke df_verify
# Pastikan shape-nya sama dengan df_gabung
#
# Expected output: 'Shape sama! (5, N)' atau pesan error jika berbeda
# ============================================================

# TODO: Simpan ke CSV
# TODO: Baca kembali ke df_verify
# TODO: Bandingkan shape

print('Verifikasi shape...')

# %% [markdown]
# **💡 Hint untuk TODO 3**: `pd.merge(df_kiri, df_kanan, on='kolom_kunci', how='inner')`
#
# **💡 Hint untuk TODO 4**: `df.to_csv('nama_file.csv', index=False)` dan `pd.read_csv('nama_file.csv')`
#
# ---
# ## 🤔 Pertanyaan Refleksi
#
# 1. Apa perbedaan antara `how='inner'`, `how='left'`, dan `how='outer'` pada merge?
# 2. Kenapa kita perlu `index=False` saat menyimpan CSV?
# 3. Kolom `tekanan_darah` ('120/80') — ini tipe data apa? Bagaimana cara mengolahnya lebih lanjut?
