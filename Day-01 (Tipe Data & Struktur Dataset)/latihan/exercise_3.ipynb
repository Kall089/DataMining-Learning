# %% [markdown]
# # 🏋️ Exercise 3: Statistik Deskriptif & Eksplorasi DataFrame
#
# **Day**: 1 | **Difficulty**: Easy-Medium
# **Topic**: describe, value_counts, groupby dasar, visualisasi sederhana
#
# ---
#
# ## 📋 Problem Statement
#
# Kamu menerima dataset penjualan dari sebuah toko retail yang memiliki 3 cabang (Jakarta, Bandung, Surabaya). Manajer ingin laporan singkat sebelum rapat besok pagi. Kamu perlu menjawab 5 pertanyaan bisnis hanya dari statistik deskriptif dan visualisasi sederhana — tanpa model ML sama sekali.
#
# Ini melatih skill paling dasar tapi paling sering dipakai: **kemampuan membaca data dan menarik insight**.
#
# ## 🎯 Learning Goals
# - Menggunakan `.describe()` untuk statistik cepat
# - Menggunakan `.groupby()` untuk agregasi per grup
# - Menjawab pertanyaan bisnis dari statistik
# - Membuat visualisasi sederhana untuk mendukung insight

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 5)
np.random.seed(42)

# Generate dataset penjualan retail
n = 200
cabang = np.random.choice(['Jakarta', 'Bandung', 'Surabaya'], size=n, p=[0.5, 0.3, 0.2])
kategori = np.random.choice(['Elektronik', 'Fashion', 'Makanan', 'Perabot'], size=n, p=[0.3, 0.35, 0.25, 0.1])

# Harga dasar per kategori
harga_base = {'Elektronik': 1500000, 'Fashion': 250000, 'Makanan': 75000, 'Perabot': 500000}
harga = np.array([harga_base[k] * (0.7 + np.random.random() * 0.8) for k in kategori])
jumlah = np.random.randint(1, 6, size=n)
total = harga * jumlah

df_penjualan = pd.DataFrame({
    'tanggal':       pd.date_range('2024-01-01', periods=n, freq='D').strftime('%Y-%m-%d'),
    'cabang':        cabang,
    'kategori':      kategori,
    'harga_satuan':  harga.round(0),
    'jumlah_terjual': jumlah,
    'total_penjualan': total.round(0),
    'metode_bayar':  np.random.choice(['Cash', 'Transfer', 'Kartu Kredit', 'QRIS'], size=n),
})

print(f'Dataset Penjualan Retail: {df_penjualan.shape[0]} transaksi')
df_penjualan.head()

# %%
# ============================================================
# TODO 1: Cetak ringkasan statistik lengkap dataset
#
# Gunakan .info(), .describe(), dan .describe(include='all')
# Dari output tersebut, jawab pertanyaan ini di print statement:
# a. Berapa rata-rata total_penjualan?
# b. Berapa jumlah transaksi per cabang?
# c. Metode bayar apa yang paling sering digunakan?
#
# Expected output: statistik + jawaban 3 pertanyaan di atas
# ============================================================

# TODO: Cetak info dan describe

# TODO: Jawab pertanyaan a, b, c
print('a. Rata-rata total penjualan: ???')
print('b. Jumlah transaksi per cabang:')
# print(...)
print('c. Metode bayar terpopuler: ???')

# %%
# ============================================================
# TODO 2: Analisis per Cabang
#
# Gunakan groupby untuk menjawab:
# a. Cabang mana yang punya total_penjualan TERTINGGI?
# b. Cabang mana yang punya rata-rata jumlah_terjual TERTINGGI?
# c. Berapa total pendapatan (sum total_penjualan) per cabang?
#
# Expected output: DataFrame agregasi + jawaban pertanyaan
# ============================================================

# TODO: groupby cabang
# Hint: df.groupby('cabang')[['total_penjualan','jumlah_terjual']].agg(['sum','mean','count'])

print('Analisis per Cabang:')
# display(...)

print('a. Cabang total penjualan tertinggi: ???')
print('b. Cabang rata-rata jumlah terjual tertinggi: ???')
print('c. Total pendapatan per cabang:')
# print(...)

# %%
# ============================================================
# TODO 3: Visualisasi — Total Penjualan per Cabang dan Kategori
#
# Buat figure dengan 1 baris 2 kolom subplots:
# - Plot kiri  : Bar chart total penjualan per cabang
# - Plot kanan : Bar chart jumlah transaksi per kategori
#
# Pastikan ada: title, xlabel, ylabel, dan tight_layout
#
# Expected output: Figure 2 subplot yang informatif
# ============================================================

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# TODO: Plot kiri — total penjualan per cabang
# Hint: groupby + plot(kind='bar')

# TODO: Plot kanan — jumlah transaksi per kategori

plt.tight_layout()
plt.show()

# %%
# ============================================================
# TODO 4: Pertanyaan Bisnis — Siapa "Star Performer"?
#
# Definisi: Kombinasi cabang + kategori dengan rata-rata
# total_penjualan tertinggi.
#
# Gunakan groupby(['cabang','kategori']) untuk mencari
# kombinasi dengan mean total_penjualan tertinggi.
#
# Expected output: Nama cabang + kategori + nilai rata-ratanya
# Contoh: 'Jakarta - Elektronik: Rp 8,500,000'
# ============================================================

# TODO: groupby 2 kolom

print('Star Performer (kombinasi cabang-kategori terbaik):')
# print(...)

# %% [markdown]
# **💡 Hint TODO 2**: `df.groupby('cabang')['total_penjualan'].sum().idxmax()` untuk mencari yang terbesar
#
# **💡 Hint TODO 4**: Setelah groupby, gunakan `.idxmax()` pada hasil mean
#
# ---
# ## 🤔 Pertanyaan Refleksi
#
# 1. Dari analisis ini, cabang mana yang perlu perhatian lebih dari manajemen? Mengapa?
# 2. Apakah rata-rata (mean) adalah metrik yang tepat untuk `total_penjualan`? Atau sebaiknya pakai median?
# 3. Insight apa lagi yang bisa kamu gali dari dataset ini tanpa model ML?
