# %% [markdown]
# # 🏋️ Exercise 5: Mini EDA — Dataset Titanic
#
# **Day**: 1 | **Difficulty**: Medium
# **Topic**: Exploratory Data Analysis, visualisasi, insight
#
# ---
#
# ## 📋 Problem Statement
#
# Dataset Titanic adalah salah satu dataset paling terkenal dalam data science. Di sini kamu tidak diminta untuk membuat model prediksi — kamu diminta untuk **memahami datanya terlebih dahulu** melalui EDA (Exploratory Data Analysis).
#
# EDA adalah proses membaca cerita dari data sebelum melakukan modeling. Tanpa EDA yang baik, model yang kamu buat akan rapuh karena kamu tidak benar-benar mengerti datanya.
#
# Tugasmu: jawab 5 pertanyaan analitis menggunakan visualisasi dan statistik deskriptif.
#
# ## 🎯 Learning Goals
# - Melakukan EDA end-to-end pada dataset nyata
# - Menggabungkan statistik deskriptif dengan visualisasi
# - Menarik insight bermakna dari data
# - Mengidentifikasi kolom yang perlu preprocessing lebih lanjut

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 5)
np.random.seed(42)

df = sns.load_dataset('titanic')
print(f'Dataset Titanic: {df.shape[0]} baris x {df.shape[1]} kolom')
print('Kolom yang tersedia:')
print(df.columns.tolist())
df.head()

# %%
# Langkah 1 — Selalu dimulai dengan ini
print('=== .info() ===')
df.info()
print()
print('=== Missing Values ===')
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(1)
print(pd.DataFrame({'jumlah_missing': missing, 'persen': missing_pct})[missing > 0])

# %%
# ============================================================
# TODO 1: Pertanyaan 1 — Berapa tingkat keselamatan (survival rate) secara keseluruhan?
#
# Hitung:
# a. Jumlah yang selamat vs tidak selamat
# b. Persentase yang selamat
# c. Buat bar chart yang menunjukkan perbandingan ini
#
# Expected output: angka survival rate + bar chart
# ============================================================

# TODO: hitung dan visualisasi
print('Survival Rate Keseluruhan:')
print('a. Jumlah selamat vs tidak selamat:')
# print(df['survived'].value_counts())
print('b. Persentase selamat: ???%')

# %%
# ============================================================
# TODO 2: Pertanyaan 2 — Apakah kelas penumpang (pclass) mempengaruhi keselamatan?
#
# Hitung survival rate per pclass (1, 2, 3)
# Buat visualisasi yang jelas untuk mendukung jawabanmu
#
# Expected output: tabel survival rate per kelas + visualisasi
# ============================================================

print('Survival Rate per Kelas:')
# TODO: groupby pclass, hitung mean survived
# TODO: visualisasi dengan bar chart

# %%
# ============================================================
# TODO 3: Pertanyaan 3 — Distribusi usia penumpang seperti apa?
#
# Buat histogram distribusi usia.
# Tandai garis mean dan median di histogram.
# Apakah distribusinya normal, skewed kiri, atau kanan?
#
# Expected output: histogram + mean + median + kesimpulan
# ============================================================

df_age = df['age'].dropna()

# TODO: Buat histogram
# Hint: plt.axvline(mean, color='red', linestyle='--', label='Mean')
#       plt.axvline(median, color='green', linestyle='--', label='Median')

print(f'Mean usia  : {df_age.mean():.1f} tahun')
print(f'Median usia: {df_age.median():.1f} tahun')
print('Distribusi: ???')

# %%
# ============================================================
# TODO 4: Pertanyaan 4 — Apakah ada perbedaan harga tiket (fare) antar kelas?
#
# Buat box plot fare per pclass.
# Identifikasi apakah ada outlier yang ekstrem.
#
# Expected output: box plot + analisis outlier
# ============================================================

# TODO: Buat box plot
# Hint: sns.boxplot(data=df, x='pclass', y='fare')
# atau: df.boxplot(column='fare', by='pclass')

print('Statistik fare per kelas:')
# print(df.groupby('pclass')['fare'].describe())

# %%
# ============================================================
# TODO 5: Ringkasan EDA — Buat 3 insight paling penting
#
# Tulis 3 insight yang kamu temukan dari analisis di atas.
# Format: angka konkret, bukan pernyataan umum.
#
# Contoh BURUK: "Kelas 1 lebih banyak selamat"
# Contoh BAIK:  "Survival rate kelas 1 (63%) hampir 3x lebih tinggi
#               dibanding kelas 3 (24%)"
#
# Expected output: 3 insight dengan angka spesifik
# ============================================================

print('=== 3 Insight Utama dari EDA Titanic ===')
print()
print('Insight 1: ???')
print()
print('Insight 2: ???')
print()
print('Insight 3: ???')

# %% [markdown]
# ---
# ## 🤔 Pertanyaan Refleksi
#
# 1. Kolom `age` memiliki ~20% missing value. Strategi apa yang akan kamu gunakan untuk mengatasinya? (Hapus baris? Isi dengan mean? Isi dengan median?)
# 2. Kolom `deck` memiliki hampir 80% missing — apakah kolom ini layak dipertahankan?
# 3. Berdasarkan EDA ini, fitur apa yang menurutmu paling penting untuk memprediksi keselamatan?
