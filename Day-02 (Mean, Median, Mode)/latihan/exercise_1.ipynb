# %% [markdown]
# # 🏋️ Exercise 1: Hitung & Bandingkan Mean vs Median
#
# **Day**: 2 | **Difficulty**: Easy
# **Topic**: Mean, Median, perbandingan, interpretasi
#
# ---
#
# ## 📋 Problem Statement
#
# Kamu bekerja sebagai data analyst di sebuah sekolah. Guru matematika memintamu menganalisis **nilai ujian** dari 3 kelas berbeda untuk menentukan kelas mana yang performanya paling "tipikal" tinggi.
#
# Setiap kelas punya karakteristik berbeda:
# - Kelas A: Semua siswa nilainya relatif seragam
# - Kelas B: Ada satu siswa yang nilainya sangat rendah (tidak masuk ujian)
# - Kelas C: Ada satu siswa yang nilainya sangat tinggi (jenius)
#
# Tugasmu: Hitung mean dan median dari ketiga kelas, tentukan mana yang lebih mewakili "nilai tipikal" kelas tersebut.
#
# ## 🎯 Learning Goals
# - [ ] Menghitung mean dan median dengan NumPy/Pandas
# - [ ] Membandingkan mean vs median pada distribusi berbeda
# - [ ] Menentukan ukuran mana yang lebih tepat berdasarkan distribusi
# - [ ] Menginterpretasi gap antara mean dan median

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

# Dataset: Nilai ujian 3 kelas (skala 0-100)
kelas_A = np.array([75, 78, 82, 80, 77, 81, 79, 83, 76, 79, 80, 82, 78, 81, 77])
kelas_B = np.array([75, 78, 82, 80, 77, 81, 79, 83, 76, 79, 80, 82, 78, 81, 10])  # 10 = outlier rendah
kelas_C = np.array([75, 78, 82, 80, 77, 81, 79, 83, 76, 79, 80, 82, 78, 81, 100]) # 100 = outlier tinggi

print('Dataset Nilai Ujian:')
print(f'  Kelas A: {kelas_A}')
print(f'  Kelas B: {kelas_B}  ← Ada outlier rendah (10)')
print(f'  Kelas C: {kelas_C}  ← Ada outlier tinggi (100)')

# %% [markdown]
# ---
# ## 📝 Langkah Pengerjaan
#
# 1. Hitung mean dan median untuk setiap kelas
# 2. Hitung gap (selisih) antara mean dan median
# 3. Tentukan ukuran mana yang lebih tepat untuk setiap kelas
# 4. Buat visualisasi perbandingan

# %%
# ============================================================
# TODO 1: Hitung mean dan median untuk setiap kelas
#
# Kamu diminta untuk:
# 1. Hitung mean dan median kelas_A, kelas_B, kelas_C
# 2. Simpan hasilnya dalam DataFrame dengan kolom:
#    'kelas', 'mean', 'median', 'gap' (mean - median)
#
# Expected output: DataFrame dengan 3 baris (A, B, C)
# Hint: gunakan np.mean() dan np.median()
# ============================================================

# Tulis kode kamu di sini ↓

# %% [markdown]
# **💡 Hint**: Gap positif (mean > median) menunjukkan outlier di atas, gap negatif (mean < median) menunjukkan outlier di bawah.
#
# **✅ Expected Output**: DataFrame yang menunjukkan:
# - Kelas A: mean ≈ median (gap kecil)
# - Kelas B: mean < median (gap negatif karena outlier rendah)
# - Kelas C: mean > median (gap positif karena outlier tinggi)

# %%
# ============================================================
# TODO 2: Tentukan ukuran yang lebih tepat untuk setiap kelas
#
# Untuk setiap kelas, jawab:
# - Apakah mean atau median yang lebih "mewakili" nilai tipikal?
# - Berikan alasan singkat
#
# Simpan jawaban dalam dictionary:
# pilihan = {'A': ('mean'/'median', 'alasan'), 'B': ..., 'C': ...}
#
# Expected: Mean tepat untuk A, Median tepat untuk B dan C
# ============================================================

# Tulis kode kamu di sini ↓
pilihan = {
    'A': ('???', 'alasan...'),
    'B': ('???', 'alasan...'),
    'C': ('???', 'alasan...'),
}

for kelas, (ukuran, alasan) in pilihan.items():
    print(f'Kelas {kelas}: Pilih {ukuran} — {alasan}')

# %%
# ============================================================
# TODO 3: Buat visualisasi histogram 3 kelas
#
# Buat figure dengan 3 subplot (1 baris, 3 kolom)
# Setiap subplot:
# - Histogram nilai kelas tersebut
# - Garis vertikal merah putus-putus untuk Mean
# - Garis vertikal hijau solid untuk Median
# - Legend dan title
#
# Hint: gunakan plt.subplots(1, 3, figsize=(15, 4))
#        dan ax.axvline() untuk garis vertikal
# ============================================================

# Tulis kode kamu di sini ↓

# %% [markdown]
# ---
# ## 🤔 Pertanyaan Refleksi
#
# 1. Jika kamu harus melaporkan "nilai rata-rata" kelas B ke orang tua siswa, mana yang kamu gunakan: mean atau median? Mengapa?
# 2. Dalam situasi apa mean dan median SANGAT berbeda nilainya?
# 3. Apakah mungkin mean = median? Berikan contoh distribusi di mana ini terjadi.
