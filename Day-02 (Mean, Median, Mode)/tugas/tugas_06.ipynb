# %% [markdown]
# # Tugas 6: Trimmed Mean untuk Skor Kompetisi
#
# ## Deskripsi
# Dalam kompetisi memasak, 10 juri memberikan skor (1-10).
# Aturan kompetisi: buang skor tertinggi dan terendah, lalu rata-ratakan sisanya.
# Lakukan:
# 1. Hitung mean biasa dari semua skor
# 2. Hitung trimmed mean 10% (buang 10% dari tiap ujung) menggunakan `scipy.stats.trim_mean`
# 3. Hitung trimmed mean 20%
# 4. Hitung median
# 5. Verifikasi manual: urutkan data, buang 1 tertinggi + 1 terendah, hitung mean sisanya
# 6. Tentukan skor mana yang paling "adil" untuk peserta

# %%
import pandas as pd
import numpy as np
from scipy.stats import trim_mean

# Skor dari 10 juri (1 juri terlalu pelit, 1 juri terlalu murah hati)
skor_juri = np.array([3.0, 7.8, 8.0, 8.2, 8.5, 8.3, 8.1, 8.4, 8.0, 9.8])

print(f'Skor juri: {skor_juri}')
print(f'Skor terurut: {np.sort(skor_juri)}')
print(f'Suspect bias rendah: {skor_juri.min()} (juri pelit)')
print(f'Suspect bias tinggi: {skor_juri.max()} (juri murah hati)')

# %%
# TODO: Kerjakan di sini

# 1. Mean biasa

# 2. Trimmed mean 10% (scipy)

# 3. Trimmed mean 20% (scipy)

# 4. Median

# 5. Verifikasi manual (buang 1 terbawah + 1 teratas)

# 6. Tentukan skor paling adil

# %% [markdown]
# ## Expected Output
# ```
# Skor juri: [3.  7.8 8.  8.2 8.5 8.3 8.1 8.4 8.  9.8]
# Skor terurut: [3.  7.8 8.  8.  8.1 8.2 8.3 8.4 8.5 9.8]
#
# === Perbandingan Ukuran ===
# Mean biasa       : 7.81
# Trimmed mean 10% : 8.16 (buang 1 dari tiap ujung)
# Trimmed mean 20% : 8.19 (buang 2 dari tiap ujung)
# Median           : 8.15
#
# === Verifikasi Manual ===
# Data setelah buang 1 terbawah + 1 teratas:
# [7.8 8.  8.  8.1 8.2 8.3 8.4 8.5]
# Mean sisanya: 8.16 ✓ (sama dengan trimmed mean 10%)
#
# Kesimpulan: Trimmed mean 10% paling adil (8.16)
# - Mean biasa (7.81) terlalu rendah karena juri pelit
# - Median (8.15) juga bagus, tapi trimmed mean lebih informatif
# ```
