# %% [markdown]
# # Tugas 7: Weighted Mean untuk Perhitungan IPK
#
# ## Deskripsi
# Hitung IPK semester ini untuk mahasiswa berikut.
# Lakukan:
# 1. Hitung mean biasa (tanpa bobot SKS)
# 2. Hitung IPK (weighted mean dengan bobot = SKS) menggunakan `np.average()`
# 3. Hitung selisih antara mean biasa dan IPK
# 4. Jelaskan mengapa IPK ≠ mean biasa
# 5. Hitung kontribusi setiap MK terhadap IPK (SKS × Nilai / Total SKS)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'Mata_Kuliah': ['Data Mining', 'Kalkulus II', 'Basis Data', 'Pancasila', 'Olahraga'],
    'SKS': [4, 4, 3, 2, 1],
    'Nilai_Huruf': ['A-', 'B+', 'A', 'A', 'B'],
    'Nilai_Angka': [3.7, 3.3, 4.0, 4.0, 3.0],
})

display(df)
print(f'Total SKS: {df["SKS"].sum()}')

# %%
# TODO: Kerjakan di sini

# 1. Mean biasa

# 2. IPK (weighted mean)

# 3. Selisih

# 4. Penjelasan

# 5. Kontribusi per MK

# %% [markdown]
# ## Expected Output
# ```
#   Mata_Kuliah  SKS Nilai_Huruf  Nilai_Angka
# 0  Data Mining    4          A-          3.7
# 1  Kalkulus II    4          B+          3.3
# 2    Basis Data    3           A          4.0
# 3    Pancasila    2           A          4.0
# 4    Olahraga    1           B          3.0
#
# === Hasil ===
# Mean biasa (tanpa bobot): 3.60
# IPK (weighted mean)     : 3.59
# Selisih                 : -0.01
#
# === Kontribusi per MK ===
#   Mata_Kuliah  SKS  Nilai  SKS×Nilai  Kontribusi_IPK
#   Data Mining    4   3.7      14.8         1.057
#   Kalkulus II    4   3.3      13.2         0.943
#   Basis Data     3   4.0      12.0         0.857
#   Pancasila      2   4.0       8.0         0.571
#   Olahraga       1   3.0       3.0         0.214
#   TOTAL         14    -       51.0         3.643 (IPK)
#
# Penjelasan: Data Mining & Kalkulus (4 SKS) menyumbang 56% dari IPK,
# sedangkan Olahraga (1 SKS) hanya menyumbang 6%.
# ```
