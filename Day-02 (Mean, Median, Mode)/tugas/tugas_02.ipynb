# %% [markdown]
# # Tugas 2: Menghitung Median untuk Data Ganjil dan Genap
#
# ## Deskripsi
# Diberikan dua dataset harga makanan (dalam ribuan Rupiah).
# Lakukan:
# 1. Urutkan kedua data dari kecil ke besar menggunakan `np.sort()`
# 2. Hitung median **secara manual** (jelaskan posisi tengahnya)
# 3. Verifikasi dengan `np.median()`
# 4. Jelaskan perbedaan cara hitung n ganjil vs n genap

# %%
import pandas as pd
import numpy as np

# Data harga makanan (ribu Rupiah)
harga_ganjil = np.array([25, 15, 45, 30, 20, 35, 50])  # 7 item
harga_genap = np.array([25, 15, 45, 30, 20, 35, 50, 40])  # 8 item

print(f'Data ganjil (n={len(harga_ganjil)}): {harga_ganjil}')
print(f'Data genap  (n={len(harga_genap)}): {harga_genap}')

# %%
# TODO: Kerjakan di sini

# 1. Urutkan data
ganjil_sorted = None
genap_sorted = None

# 2. Hitung median manual
# Ganjil: posisi tengah = (n+1)/2
median_ganjil_manual = None

# Genap: rata-rata 2 nilai tengah
median_genap_manual = None

# 3. Verifikasi
median_ganjil_numpy = None
median_genap_numpy = None

# 4. Print hasil

# %% [markdown]
# ## Expected Output
# ```
# Data ganjil (n=7): [25 15 45 30 20 35 50]
# Data genap  (n=8): [25 15 45 30 20 35 50 40]
#
# === Data Ganjil (n=7) ===
# Data terurut: [15 20 25 30 35 45 50]
# Posisi tengah: (7+1)/2 = 4
# Median (manual): 30 (nilai di posisi ke-4)
# Median (numpy) : 30.0 ✓
#
# === Data Genap (n=8) ===
# Data terurut: [15 20 25 30 35 40 45 50]
# Posisi tengah: 4 dan 5
# Median (manual): (30 + 35) / 2 = 32.5
# Median (numpy) : 32.5 ✓
# ```
