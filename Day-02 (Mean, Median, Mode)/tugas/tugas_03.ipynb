# %% [markdown]
# # Tugas 3: Menghitung Mode dari Data Kategorik dan Numerik
#
# ## Deskripsi
# Diberikan data survei pelanggan restoran.
# Lakukan:
# 1. Hitung mode kolom `metode_bayar` (kategorik) menggunakan `.mode()`
# 2. Hitung mode kolom `rating` (numerik)
# 3. Hitung mode kolom `jumlah_orang` — identifikasi jika **bimodal**
# 4. Tampilkan `value_counts()` untuk setiap kolom sebagai verifikasi

# %%
import pandas as pd
import numpy as np
from scipy import stats

df = pd.DataFrame({
    'pelanggan': ['P01','P02','P03','P04','P05','P06','P07','P08','P09','P10','P11','P12'],
    'metode_bayar': ['QRIS','Cash','QRIS','Transfer','QRIS','Cash','QRIS','QRIS','Cash','Transfer','QRIS','Cash'],
    'rating': [4, 5, 4, 3, 4, 5, 4, 3, 4, 5, 4, 3],
    'jumlah_orang': [2, 4, 2, 1, 4, 2, 4, 1, 2, 4, 2, 4],
})
display(df)

# %%
# TODO: Kerjakan di sini

# 1. Mode metode_bayar

# 2. Mode rating

# 3. Mode jumlah_orang (cek bimodal!)

# 4. Value counts untuk verifikasi

# %% [markdown]
# ## Expected Output
# ```
# === Mode metode_bayar ===
# Mode: QRIS (muncul 6x dari 12 data)
#
# === Mode rating ===
# Mode: 4 (muncul 7x dari 12 data)
#
# === Mode jumlah_orang ===
# Mode: [2, 4] → BIMODAL! (masing-masing muncul 5x)
#
# === Value Counts ===
# metode_bayar:
#   QRIS        6
#   Cash        4
#   Transfer    2
#
# rating:
#   4    7
#   5    3
#   3    3 → Catatan: 5 dan 3 sama-sama 3x, tapi 4 dominan
#
# jumlah_orang:
#   2    5
#   4    5  → Bimodal!
#   1    2
# ```
