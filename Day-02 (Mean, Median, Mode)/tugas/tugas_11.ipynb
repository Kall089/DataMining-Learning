# %% [markdown]
# # Tugas 11: Grouped Statistics dengan Dataset Tips
#
# ## Deskripsi
# Load dataset `tips` dari Seaborn.
# Lakukan:
# 1. Hitung mean, median, skewness kolom `total_bill` per `day`
# 2. Hitung mean, median, skewness kolom `tip` per `time` (Lunch/Dinner)
# 3. Hitung mean-median gap (%) untuk setiap grup
# 4. Identifikasi kombinasi yang paling skewed
# 5. Buat grouped bar chart: mean vs median per hari

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
print(f'Dataset tips: {tips.shape}')
print(tips.head())
print(f'\nHari: {tips["day"].unique()}')
print(f'Time: {tips["time"].unique()}')

# %%
# TODO: Kerjakan di sini

# 1. Statistik total_bill per day

# 2. Statistik tip per time

# 3. Gap (%)

# 4. Identifikasi paling skewed

# 5. Visualisasi

# %% [markdown]
# ## Expected Output
# ```
# === total_bill per Day ===
#       day   mean  median  skewness  gap_persen
# 0    Thur  17.68   16.20      1.13       9.1%
# 1     Fri  17.15   15.38      1.09      11.5%
# 2     Sat  20.44   18.24      0.86      12.1%
# 3     Sun  21.41   19.63      1.05       9.1%
#
# === tip per Time ===
#      time  mean  median  skewness  gap_persen
# 0   Lunch  2.73    2.25      1.25      21.3%
# 1  Dinner  3.10    2.75      1.41      12.7%
#
# Paling skewed: Dinner tips (skewness=1.41)
# Artinya ada beberapa pelanggan yang memberi tip sangat besar.
#
# [+ grouped bar chart mean vs median per hari]
# ```
