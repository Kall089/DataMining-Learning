# %% [markdown]
# # Tugas 5: Efek Outlier pada Mean vs Median
#
# ## Deskripsi
# Diberikan data harga rumah di sebuah perumahan (dalam miliar Rupiah).
# Lakukan:
# 1. Hitung mean dan median data **tanpa** outlier
# 2. Tambahkan 1 outlier (rumah mewah Rp 25 Miliar) ke data
# 3. Hitung mean dan median data **dengan** outlier
# 4. Hitung perubahan (%) untuk mean dan median
# 5. Jelaskan mengapa median lebih `resistant`

# %%
import pandas as pd
import numpy as np

# Harga rumah di perumahan (miliar Rupiah)
harga_normal = np.array([1.2, 1.5, 1.3, 1.8, 1.4, 1.6, 1.5, 1.7, 1.3, 1.4])

# Ada 1 rumah mewah (outlier)
harga_dengan_outlier = np.append(harga_normal, 25.0)

print(f'Data normal (n={len(harga_normal)}): {harga_normal}')
print(f'Data + outlier (n={len(harga_dengan_outlier)}): {harga_dengan_outlier}')

# %%
# TODO: Kerjakan di sini

# 1. Mean & median tanpa outlier

# 2-3. Mean & median dengan outlier

# 4. Hitung perubahan (%)

# 5. Print penjelasan

# %% [markdown]
# ## Expected Output
# ```
# === Tanpa Outlier ===
# Mean  : Rp 1.47 Miliar
# Median: Rp 1.45 Miliar
#
# === Dengan Outlier (+ rumah Rp 25M) ===
# Mean  : Rp 3.61 Miliar  ← MELONJAK!
# Median: Rp 1.50 Miliar  ← Hampir tidak berubah
#
# === Perubahan ===
# Mean  : +145.6% (dari 1.47 → 3.61)
# Median: +3.4%   (dari 1.45 → 1.50)
#
# Kesimpulan: Median RESISTANT terhadap outlier.
# Satu rumah mewah mengubah mean +145% tapi median hanya +3%.
# ```
