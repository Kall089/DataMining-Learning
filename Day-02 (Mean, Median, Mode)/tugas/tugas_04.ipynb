# %% [markdown]
# # Tugas 4: Membandingkan Mean dan Median pada Distribusi Berbeda
#
# ## Deskripsi
# Diberikan data penghasilan bulanan (juta Rupiah) dari 3 kelompok profesi.
# Lakukan:
# 1. Hitung mean dan median untuk setiap kelompok
# 2. Hitung selisih (gap) = mean - median
# 3. Tentukan distribusi setiap kelompok: simetris / right-skewed / left-skewed
# 4. Tentukan ukuran mana yang lebih tepat (mean/median) untuk setiap kelompok
# 5. Buat DataFrame ringkasan

# %%
import pandas as pd
import numpy as np

# Penghasilan bulanan (juta Rupiah)
guru = np.array([4.5, 5.0, 4.8, 5.2, 4.9, 5.1, 4.7, 5.0, 4.8, 5.3])
startup = np.array([5, 6, 5, 7, 6, 8, 5, 6, 45, 80])  # Ada founder kaya
dokter = np.array([50, 45, 48, 52, 47, 15, 10, 49, 51, 46])  # Ada yang baru mulai

print('Guru     :', guru)
print('Startup  :', startup)
print('Dokter   :', dokter)

# %%
# TODO: Kerjakan di sini

# Buat DataFrame ringkasan dengan kolom:
# profesi, mean, median, gap, distribusi, ukuran_tepat

# %% [markdown]
# ## Expected Output
# ```
#    profesi   mean  median    gap      distribusi  ukuran_tepat
# 0     Guru   4.93    4.95  -0.02        Simetris          Mean
# 1  Startup  17.30    6.00  11.30   Right-skewed        Median
# 2   Dokter  41.30   47.50  -6.20    Left-skewed        Median
#
# Interpretasi:
# - Guru: mean ≈ median → distribusi seragam, keduanya tepat
# - Startup: mean >> median → ada founder dengan gaji 45-80jt yang inflate mean
# - Dokter: mean << median → ada dokter muda (10-15jt) yang tarik mean turun
# ```
