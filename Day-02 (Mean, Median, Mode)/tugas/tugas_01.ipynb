# %% [markdown]
# # Tugas 1: Menghitung Mean Secara Manual dan NumPy
#
# ## Deskripsi
# Diberikan data nilai ujian 8 mahasiswa berikut.
# Lakukan:
# 1. Hitung mean **secara manual** (jumlah semua / banyak data) — simpan di variabel `mean_manual`
# 2. Hitung mean menggunakan `np.mean()` — simpan di variabel `mean_numpy`
# 3. Hitung mean menggunakan `pd.Series.mean()` — simpan di variabel `mean_pandas`
# 4. Print ketiga hasil dengan format f-string 2 desimal
# 5. Verifikasi ketiganya sama

# %%
import pandas as pd
import numpy as np

nilai = np.array([78, 85, 92, 64, 71, 88, 95, 55])
print(f'Data nilai: {nilai}')
print(f'Jumlah data: {len(nilai)}')

# %%
# TODO: Kerjakan di sini

# 1. Hitung manual
mean_manual = None  # sum(nilai) / len(nilai)

# 2. Hitung dengan NumPy
mean_numpy = None

# 3. Hitung dengan Pandas
mean_pandas = None

# 4. Print hasil
print(f'Mean (manual) : {mean_manual}')
print(f'Mean (numpy)  : {mean_numpy}')
print(f'Mean (pandas) : {mean_pandas}')

# %% [markdown]
# ## Expected Output
# ```
# Data nilai: [78 85 92 64 71 88 95 55]
# Jumlah data: 8
# Mean (manual) : 78.50
# Mean (numpy)  : 78.50
# Mean (pandas) : 78.50
# ```
