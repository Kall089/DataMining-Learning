# %% [markdown]
# # Tugas 13: Simulasi Central Limit Theorem
#
# ## Deskripsi
# Buktikan bahwa sampling distribution of mean mendekati normal,
# meskipun populasi TIDAK normal (right-skewed).
# Lakukan:
# 1. Buat populasi right-skewed (exponential) dengan 100000 data
# 2. Ambil 500 random sampel, masing-masing ukuran n=30
# 3. Hitung mean setiap sampel → simpan di list `sampling_means`
# 4. Hitung median setiap sampel → simpan di list `sampling_medians`
# 5. Plot: (a) populasi, (b) distribusi sampling means, (c) distribusi sampling medians
# 6. Bandingkan mean dari sampling_means dengan population mean

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# Populasi right-skewed (waktu tunggu customer service dalam menit)
populasi = np.random.exponential(scale=5, size=100000)

print(f'=== Populasi (n=100,000) ===')
print(f'  Mean populasi  : {np.mean(populasi):.4f}')
print(f'  Median populasi: {np.median(populasi):.4f}')
print(f'  Skewness       : {pd.Series(populasi).skew():.4f} (right-skewed!)')

n_sampel = 500
ukuran_sampel = 30

# %%
# TODO: Kerjakan di sini

# 2-4. Sampling loop
sampling_means = []
sampling_medians = []

# for i in range(n_sampel):
#     sampel = ...
#     sampling_means.append(...)
#     sampling_medians.append(...)

# 5. Plot (3 subplot)

# 6. Bandingkan

# %% [markdown]
# ## Expected Output
# ```
# === Populasi (n=100,000) ===
#   Mean populasi  : ~5.0
#   Median populasi: ~3.5
#   Skewness       : ~2.0 (right-skewed!)
#
# === Sampling Distribution (500 sampel, n=30) ===
#   Mean dari sampling_means  : ~5.0 (≈ population mean!)
#   Std dari sampling_means   : ~0.9
#   Skewness sampling_means   : ~0.3 (mendekati normal!)
#
#   Mean dari sampling_medians: ~3.5 (≈ population median!)
#   Std dari sampling_medians : ~0.7
#
# CLT terbukti: meskipun populasi SANGAT skewed,
# distribusi rata-rata sampel mendekati NORMAL.
#
# [+ 3 subplot: populasi skewed, sampling means ~normal, sampling medians ~normal]
# ```
