# %% [markdown]
# # Tugas 8: Menentukan Skewness dan Arah Distribusi
#
# ## Deskripsi
# Diberikan 3 dataset yang masing-masing punya bentuk distribusi berbeda.
# Lakukan:
# 1. Hitung mean, median, dan skewness (`.skew()`) untuk setiap dataset
# 2. Tentukan arah distribusi: simetris / right-skewed / left-skewed
# 3. Verifikasi dengan aturan: mean > median → right-skewed, mean < median → left-skewed
# 4. Buat histogram sederhana untuk visualisasi (3 subplot)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# Dataset A: Waktu pelayanan bank (menit) — kebanyakan cepat, kadang lama
waktu_bank = np.array([3, 4, 3, 5, 4, 3, 6, 4, 3, 5, 4, 3, 4, 5, 25, 30, 4, 3, 5, 4])

# Dataset B: Tinggi badan mahasiswa pria (cm) — normal/simetris
tinggi_badan = np.array([168, 172, 170, 175, 169, 171, 173, 170, 174, 169, 171, 172, 168, 173, 170])

# Dataset C: Nilai ujian kelas pintar — kebanyakan tinggi, sedikit rendah
nilai_pintar = np.array([92, 88, 95, 90, 87, 93, 91, 85, 94, 89, 45, 50, 91, 90, 93])

print(f'Waktu bank  : {waktu_bank}')
print(f'Tinggi badan: {tinggi_badan}')
print(f'Nilai pintar: {nilai_pintar}')

# %%
# TODO: Kerjakan di sini

# 1-3. Hitung dan buat tabel ringkasan

# 4. Buat histogram (fig, axes = plt.subplots(1, 3, figsize=(15, 4)))

# %% [markdown]
# ## Expected Output
# ```
# === Ringkasan Distribusi ===
#       dataset     mean  median  skewness   distribusi
# 0  Waktu Bank     6.35    4.00     2.36  Right-skewed
# 1 Tinggi Badan  170.93  171.00    -0.03      Simetris
# 2 Nilai Pintar   84.87   90.00    -1.50   Left-skewed
#
# Verifikasi:
# - Waktu Bank: mean (6.35) > median (4.00) → Right-skewed ✓
#   (Ada antrian panjang 25-30 menit yang inflate mean)
# - Tinggi Badan: mean (170.93) ≈ median (171.00) → Simetris ✓
# - Nilai Pintar: mean (84.87) < median (90.00) → Left-skewed ✓
#   (Ada 2 siswa yang nilainya jauh di bawah kelas)
# ```
